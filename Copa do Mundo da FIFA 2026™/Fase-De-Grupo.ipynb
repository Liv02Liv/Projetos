# %%
#Importação das bibliotecas.
import pandas as pd 

df = pd.read_csv("Copa-do-Mundo-da-FIFA-2026.csv", index_col= False, sep= ";")
df
# Out:
#              Equipes  Pts  PJ  VIT  E  DER  GM  GC  SG
# 0             México    9   3    3  0    0   6   0   6
# 1      África do Sul    4   3    1  1    1   2   3  -1
# 2      Coreia do Sul    3   3    1  0    2   2   3  -1
# 3   República Tcheca    1   3    0  1    2   2   6  -4
# 4              Suíça    7   3    2  1    0   7   3   4
# 5             Canadá    4   3    1  1    1   8   3   5
# 6             Bósnia    4   3    1  1    1   5   6  -1
# 7              Catar    1   3    0  1    2   2  10  -8
# 8             Brasil    7   3    2  1    0   7   1   6
# 9           Marrocos    7   3    2  1    0   6   3   3
# 10           Escócia    3   3    1  0    2   1   4  -3
# 11             Haiti    0   3    0  0    3   2   8  -6
# 12    Estados Unidos    6   3    2  0    1   8   4   4
# 13         Austrália    4   3    1  1    1   2   2   0
# 14          Paraguai    4   3    1  1    1   2   4  -2
# 15           Turquia    3   3    1  0    2   3   5  -2
# 16          Alemanha    6   3    2  0    1  10   4   6
# 17   Costa do Marfim    6   3    2  0    1   4   2   2
# 18           Equador    4   3    1  1    1   2   2   0
# 19           Curacao    1   3    0  1    2   1   9  -8
# 20           Holanda    7   3    2  1    0  10   4   6
# 21             Japão    5   3    1  2    0   7   3   4
# 22            Suécia    4   3    1  1    1   7   7   0
# 23           Tunísia    0   3    0  0    3   2  12 -10
# 24           Bélgica    5   3    1  2    0   6   2   4
# 25             Egito    5   3    1  2    0   5   3   2
# 26               Irã    3   3    0  3    0   3   3   0
# 27     Nova Zelândia    1   3    0  1    2   4  10  -6
# 28           Espanha    7   3    2  1    0   5   0   5
# 29        Cabo Verde    3   3    0  3    0   2   2   0
# 30           Uruguai    2   3    0  2    1   3   4  -1
# 31    Arábia Saudita    2   3    0  2    1   1   5  -4
# 32            França    9   3    3  0    0  10   2   8
# 33           Noruega    6   3    2  0    1   8   7   1
# 34           Senegal    3   3    1  0    2   8   6   2
# 35            Iraque    0   3    0  0    3   1  12 -11
# 36         Argentina    9   3    3  0    0   8   1   7
# 37           Áustria    4   3    1  1    1   6   6   0
# 38           Argélia    4   3    1  1    1   5   7   0
# 39          Jordânia    0   3    0  0    3   3   8  -5
# 40          Colômbia    7   3    2  1    0   4   1   3
# 41          Portugal    5   3    1  2    0   6   1   5
# 42          RD Congo    4   3    1  1    1   4   3   1
# 43       Uzbequistão    0   3    0  0    3   2  11  -9
# 44        Inglaterra    7   3    2  1    0   6   2   4
# 45           Croácia    6   3    2  0    1   5   5   0
# 46              Gana    4   3    1  1    1   2   2   0
# 47            Panamá    0   3    0  0    3   0   4  -4

# %%
print("1. Desempenho das equipes")
# Out:
# 1. Desempenho das equipes

# %%
print("Qual seleção fez mais pontos?")
df.nlargest(1, "Pts")[["Equipes", "Pts"]].style.hide(axis="index")
# Out:
# Qual seleção fez mais pontos?
# <style type="text/css">
# </style>
# <table id="T_fa978">
#   <thead>
#     <tr>
#       <th id="T_fa978_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_fa978_level0_col1" class="col_heading level0 col1" >Pts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fa978_row0_col0" class="data row0 col0" >México</td>
#       <td id="T_fa978_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Quais seleções terminaram invictas?")
df[df["DER"] == 0][["Equipes", "PJ", "VIT", "E", "DER"]].style.hide(axis="index")
# Out:
# Quais seleções terminaram invictas?
# <style type="text/css">
# </style>
# <table id="T_62c09">
#   <thead>
#     <tr>
#       <th id="T_62c09_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_62c09_level0_col1" class="col_heading level0 col1" >PJ</th>
#       <th id="T_62c09_level0_col2" class="col_heading level0 col2" >VIT</th>
#       <th id="T_62c09_level0_col3" class="col_heading level0 col3" >E</th>
#       <th id="T_62c09_level0_col4" class="col_heading level0 col4" >DER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_62c09_row0_col0" class="data row0 col0" >México</td>
#       <td id="T_62c09_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_62c09_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_62c09_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_62c09_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row1_col0" class="data row1 col0" >Suíça</td>
#       <td id="T_62c09_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_62c09_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_62c09_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_62c09_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row2_col0" class="data row2 col0" >Brasil</td>
#       <td id="T_62c09_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_62c09_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_62c09_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_62c09_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row3_col0" class="data row3 col0" >Marrocos</td>
#       <td id="T_62c09_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_62c09_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_62c09_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_62c09_row3_col4" class="data row3 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row4_col0" class="data row4 col0" >Holanda</td>
#       <td id="T_62c09_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_62c09_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_62c09_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_62c09_row4_col4" class="data row4 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row5_col0" class="data row5 col0" >Japão</td>
#       <td id="T_62c09_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_62c09_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_62c09_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_62c09_row5_col4" class="data row5 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row6_col0" class="data row6 col0" >Bélgica</td>
#       <td id="T_62c09_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_62c09_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_62c09_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_62c09_row6_col4" class="data row6 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row7_col0" class="data row7 col0" >Egito</td>
#       <td id="T_62c09_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_62c09_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_62c09_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_62c09_row7_col4" class="data row7 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row8_col0" class="data row8 col0" >Irã</td>
#       <td id="T_62c09_row8_col1" class="data row8 col1" >3</td>
#       <td id="T_62c09_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_62c09_row8_col3" class="data row8 col3" >3</td>
#       <td id="T_62c09_row8_col4" class="data row8 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row9_col0" class="data row9 col0" >Espanha</td>
#       <td id="T_62c09_row9_col1" class="data row9 col1" >3</td>
#       <td id="T_62c09_row9_col2" class="data row9 col2" >2</td>
#       <td id="T_62c09_row9_col3" class="data row9 col3" >1</td>
#       <td id="T_62c09_row9_col4" class="data row9 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row10_col0" class="data row10 col0" >Cabo Verde</td>
#       <td id="T_62c09_row10_col1" class="data row10 col1" >3</td>
#       <td id="T_62c09_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_62c09_row10_col3" class="data row10 col3" >3</td>
#       <td id="T_62c09_row10_col4" class="data row10 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row11_col0" class="data row11 col0" >França</td>
#       <td id="T_62c09_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_62c09_row11_col2" class="data row11 col2" >3</td>
#       <td id="T_62c09_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_62c09_row11_col4" class="data row11 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row12_col0" class="data row12 col0" >Argentina</td>
#       <td id="T_62c09_row12_col1" class="data row12 col1" >3</td>
#       <td id="T_62c09_row12_col2" class="data row12 col2" >3</td>
#       <td id="T_62c09_row12_col3" class="data row12 col3" >0</td>
#       <td id="T_62c09_row12_col4" class="data row12 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row13_col0" class="data row13 col0" >Colômbia</td>
#       <td id="T_62c09_row13_col1" class="data row13 col1" >3</td>
#       <td id="T_62c09_row13_col2" class="data row13 col2" >2</td>
#       <td id="T_62c09_row13_col3" class="data row13 col3" >1</td>
#       <td id="T_62c09_row13_col4" class="data row13 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row14_col0" class="data row14 col0" >Portugal</td>
#       <td id="T_62c09_row14_col1" class="data row14 col1" >3</td>
#       <td id="T_62c09_row14_col2" class="data row14 col2" >1</td>
#       <td id="T_62c09_row14_col3" class="data row14 col3" >2</td>
#       <td id="T_62c09_row14_col4" class="data row14 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_62c09_row15_col0" class="data row15 col0" >Inglaterra</td>
#       <td id="T_62c09_row15_col1" class="data row15 col1" >3</td>
#       <td id="T_62c09_row15_col2" class="data row15 col2" >2</td>
#       <td id="T_62c09_row15_col3" class="data row15 col3" >1</td>
#       <td id="T_62c09_row15_col4" class="data row15 col4" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Quais tiveram o pior desempenho?")
df.nsmallest(10, "Pts")[["Equipes", "Pts"]].style.hide(axis="index")
# Out:
# Quais tiveram o pior desempenho?
# <style type="text/css">
# </style>
# <table id="T_ae2c6">
#   <thead>
#     <tr>
#       <th id="T_ae2c6_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_ae2c6_level0_col1" class="col_heading level0 col1" >Pts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ae2c6_row0_col0" class="data row0 col0" >Haiti</td>
#       <td id="T_ae2c6_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_ae2c6_row1_col0" class="data row1 col0" >Tunísia</td>
#       <td id="T_ae2c6_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_ae2c6_row2_col0" class="data row2 col0" >Iraque</td>
#       <td id="T_ae2c6_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_ae2c6_row3_col0" class="data row3 col0" >Jordânia</td>
#       <td id="T_ae2c6_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_ae2c6_row4_col0" class="data row4 col0" >Uzbequistão</td>
#       <td id="T_ae2c6_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_ae2c6_row5_col0" class="data row5 col0" >Panamá</td>
#       <td id="T_ae2c6_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_ae2c6_row6_col0" class="data row6 col0" >República Tcheca</td>
#       <td id="T_ae2c6_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ae2c6_row7_col0" class="data row7 col0" >Catar</td>
#       <td id="T_ae2c6_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ae2c6_row8_col0" class="data row8 col0" >Curacao</td>
#       <td id="T_ae2c6_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ae2c6_row9_col0" class="data row9 col0" >Nova Zelândia</td>
#       <td id="T_ae2c6_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Quem venceu mais partidas?")
df.nlargest(10, "VIT")[["Equipes", "VIT"]].style.hide(axis="index")
# Out:
# Quem venceu mais partidas?
# <style type="text/css">
# </style>
# <table id="T_222ae">
#   <thead>
#     <tr>
#       <th id="T_222ae_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_222ae_level0_col1" class="col_heading level0 col1" >VIT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_222ae_row0_col0" class="data row0 col0" >México</td>
#       <td id="T_222ae_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_222ae_row1_col0" class="data row1 col0" >França</td>
#       <td id="T_222ae_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_222ae_row2_col0" class="data row2 col0" >Argentina</td>
#       <td id="T_222ae_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_222ae_row3_col0" class="data row3 col0" >Suíça</td>
#       <td id="T_222ae_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_222ae_row4_col0" class="data row4 col0" >Brasil</td>
#       <td id="T_222ae_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_222ae_row5_col0" class="data row5 col0" >Marrocos</td>
#       <td id="T_222ae_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_222ae_row6_col0" class="data row6 col0" >Estados Unidos</td>
#       <td id="T_222ae_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_222ae_row7_col0" class="data row7 col0" >Alemanha</td>
#       <td id="T_222ae_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_222ae_row8_col0" class="data row8 col0" >Costa do Marfim</td>
#       <td id="T_222ae_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_222ae_row9_col0" class="data row9 col0" >Holanda</td>
#       <td id="T_222ae_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Quem perdeu mais partidas?")
df.nlargest(10, "DER")[["Equipes", "DER"]].style.hide(axis="index")
# Out:
# Quem perdeu mais partidas?
# <style type="text/css">
# </style>
# <table id="T_5fcf1">
#   <thead>
#     <tr>
#       <th id="T_5fcf1_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_5fcf1_level0_col1" class="col_heading level0 col1" >DER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5fcf1_row0_col0" class="data row0 col0" >Haiti</td>
#       <td id="T_5fcf1_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5fcf1_row1_col0" class="data row1 col0" >Tunísia</td>
#       <td id="T_5fcf1_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5fcf1_row2_col0" class="data row2 col0" >Iraque</td>
#       <td id="T_5fcf1_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5fcf1_row3_col0" class="data row3 col0" >Jordânia</td>
#       <td id="T_5fcf1_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5fcf1_row4_col0" class="data row4 col0" >Uzbequistão</td>
#       <td id="T_5fcf1_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5fcf1_row5_col0" class="data row5 col0" >Panamá</td>
#       <td id="T_5fcf1_row5_col1" class="data row5 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5fcf1_row6_col0" class="data row6 col0" >Coreia do Sul</td>
#       <td id="T_5fcf1_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_5fcf1_row7_col0" class="data row7 col0" >República Tcheca</td>
#       <td id="T_5fcf1_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_5fcf1_row8_col0" class="data row8 col0" >Catar</td>
#       <td id="T_5fcf1_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_5fcf1_row9_col0" class="data row9 col0" >Escócia</td>
#       <td id="T_5fcf1_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("2. Ataque e defesa")
# Out:
# 2. Ataque e defesa

# %%
print("Melhor ataque:")
df.nlargest(10, "GM")[["Equipes", "GM"]].style.hide(axis="index")
# Out:
# Melhor ataque:
# <style type="text/css">
# </style>
# <table id="T_13a4e">
#   <thead>
#     <tr>
#       <th id="T_13a4e_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_13a4e_level0_col1" class="col_heading level0 col1" >GM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_13a4e_row0_col0" class="data row0 col0" >Alemanha</td>
#       <td id="T_13a4e_row0_col1" class="data row0 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_13a4e_row1_col0" class="data row1 col0" >Holanda</td>
#       <td id="T_13a4e_row1_col1" class="data row1 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_13a4e_row2_col0" class="data row2 col0" >França</td>
#       <td id="T_13a4e_row2_col1" class="data row2 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_13a4e_row3_col0" class="data row3 col0" >Canadá</td>
#       <td id="T_13a4e_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_13a4e_row4_col0" class="data row4 col0" >Estados Unidos</td>
#       <td id="T_13a4e_row4_col1" class="data row4 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_13a4e_row5_col0" class="data row5 col0" >Noruega</td>
#       <td id="T_13a4e_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_13a4e_row6_col0" class="data row6 col0" >Senegal</td>
#       <td id="T_13a4e_row6_col1" class="data row6 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_13a4e_row7_col0" class="data row7 col0" >Argentina</td>
#       <td id="T_13a4e_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_13a4e_row8_col0" class="data row8 col0" >Suíça</td>
#       <td id="T_13a4e_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_13a4e_row9_col0" class="data row9 col0" >Brasil</td>
#       <td id="T_13a4e_row9_col1" class="data row9 col1" >7</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Melhor defesa:")
df.nsmallest(10, "GC")[["Equipes", "GC"]].style.hide(axis="index")
# Out:
# Melhor defesa:
# <style type="text/css">
# </style>
# <table id="T_aa9e4">
#   <thead>
#     <tr>
#       <th id="T_aa9e4_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_aa9e4_level0_col1" class="col_heading level0 col1" >GC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aa9e4_row0_col0" class="data row0 col0" >México</td>
#       <td id="T_aa9e4_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aa9e4_row1_col0" class="data row1 col0" >Espanha</td>
#       <td id="T_aa9e4_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aa9e4_row2_col0" class="data row2 col0" >Brasil</td>
#       <td id="T_aa9e4_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_aa9e4_row3_col0" class="data row3 col0" >Argentina</td>
#       <td id="T_aa9e4_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_aa9e4_row4_col0" class="data row4 col0" >Colômbia</td>
#       <td id="T_aa9e4_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_aa9e4_row5_col0" class="data row5 col0" >Portugal</td>
#       <td id="T_aa9e4_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_aa9e4_row6_col0" class="data row6 col0" >Austrália</td>
#       <td id="T_aa9e4_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_aa9e4_row7_col0" class="data row7 col0" >Costa do Marfim</td>
#       <td id="T_aa9e4_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_aa9e4_row8_col0" class="data row8 col0" >Equador</td>
#       <td id="T_aa9e4_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_aa9e4_row9_col0" class="data row9 col0" >Bélgica</td>
#       <td id="T_aa9e4_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Existe relação entre gols marcados e pontos?")
df[["GM", "Pts"]].corr().style.hide(axis="index")
#Se o valor estiver próximo de 1, existe uma forte relação positiva.
# Out:
# Existe relação entre gols marcados e pontos?
# <style type="text/css">
# </style>
# <table id="T_65dda">
#   <thead>
#     <tr>
#       <th id="T_65dda_level0_col0" class="col_heading level0 col0" >GM</th>
#       <th id="T_65dda_level0_col1" class="col_heading level0 col1" >Pts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_65dda_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_65dda_row0_col1" class="data row0 col1" >0.726668</td>
#     </tr>
#     <tr>
#       <td id="T_65dda_row1_col0" class="data row1 col0" >0.726668</td>
#       <td id="T_65dda_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Melhor saldo de gols:")
df.nlargest(10, "SG")[["Equipes", "SG"]].style.hide(axis="index")
# Out:
# Melhor saldo de gols:
# <style type="text/css">
# </style>
# <table id="T_15de5">
#   <thead>
#     <tr>
#       <th id="T_15de5_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_15de5_level0_col1" class="col_heading level0 col1" >SG</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_15de5_row0_col0" class="data row0 col0" >França</td>
#       <td id="T_15de5_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_15de5_row1_col0" class="data row1 col0" >Argentina</td>
#       <td id="T_15de5_row1_col1" class="data row1 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_15de5_row2_col0" class="data row2 col0" >México</td>
#       <td id="T_15de5_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_15de5_row3_col0" class="data row3 col0" >Brasil</td>
#       <td id="T_15de5_row3_col1" class="data row3 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_15de5_row4_col0" class="data row4 col0" >Alemanha</td>
#       <td id="T_15de5_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_15de5_row5_col0" class="data row5 col0" >Holanda</td>
#       <td id="T_15de5_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_15de5_row6_col0" class="data row6 col0" >Canadá</td>
#       <td id="T_15de5_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_15de5_row7_col0" class="data row7 col0" >Espanha</td>
#       <td id="T_15de5_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_15de5_row8_col0" class="data row8 col0" >Portugal</td>
#       <td id="T_15de5_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_15de5_row9_col0" class="data row9 col0" >Suíça</td>
#       <td id="T_15de5_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("3. Eficiência")
# Out:
# 3. Eficiência

# %%
df["Aproveitamento (%)"] = (df["Pts"] / (df["PJ"] * 3)) * 100

df["GM/Jogo"] = df["GM"] / df["PJ"]

df["GC/Jogo"] = df["GC"] / df["PJ"]

df["Pts/Jogo"] = df["Pts"] / df["PJ"]

df["SG/Jogo"] = df["SG"] / df["PJ"]

df_metricas = df[[
    "Equipes",
    "Aproveitamento (%)",
    "GM/Jogo",
    "GC/Jogo",
    "Pts/Jogo",
    "SG/Jogo"
]].style.hide(axis="index")

df_metricas
# Out:
# <style type="text/css">
# </style>
# <table id="T_8d1b6">
#   <thead>
#     <tr>
#       <th id="T_8d1b6_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_8d1b6_level0_col1" class="col_heading level0 col1" >Aproveitamento (%)</th>
#       <th id="T_8d1b6_level0_col2" class="col_heading level0 col2" >GM/Jogo</th>
#       <th id="T_8d1b6_level0_col3" class="col_heading level0 col3" >GC/Jogo</th>
#       <th id="T_8d1b6_level0_col4" class="col_heading level0 col4" >Pts/Jogo</th>
#       <th id="T_8d1b6_level0_col5" class="col_heading level0 col5" >SG/Jogo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8d1b6_row0_col0" class="data row0 col0" >México</td>
#       <td id="T_8d1b6_row0_col1" class="data row0 col1" >100.000000</td>
#       <td id="T_8d1b6_row0_col2" class="data row0 col2" >2.000000</td>
#       <td id="T_8d1b6_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_8d1b6_row0_col4" class="data row0 col4" >3.000000</td>
#       <td id="T_8d1b6_row0_col5" class="data row0 col5" >2.000000</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row1_col0" class="data row1 col0" >África do Sul</td>
#       <td id="T_8d1b6_row1_col1" class="data row1 col1" >44.444444</td>
#       <td id="T_8d1b6_row1_col2" class="data row1 col2" >0.666667</td>
#       <td id="T_8d1b6_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_8d1b6_row1_col4" class="data row1 col4" >1.333333</td>
#       <td id="T_8d1b6_row1_col5" class="data row1 col5" >-0.333333</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row2_col0" class="data row2 col0" >Coreia do Sul</td>
#       <td id="T_8d1b6_row2_col1" class="data row2 col1" >33.333333</td>
#       <td id="T_8d1b6_row2_col2" class="data row2 col2" >0.666667</td>
#       <td id="T_8d1b6_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_8d1b6_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_8d1b6_row2_col5" class="data row2 col5" >-0.333333</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row3_col0" class="data row3 col0" >República Tcheca</td>
#       <td id="T_8d1b6_row3_col1" class="data row3 col1" >11.111111</td>
#       <td id="T_8d1b6_row3_col2" class="data row3 col2" >0.666667</td>
#       <td id="T_8d1b6_row3_col3" class="data row3 col3" >2.000000</td>
#       <td id="T_8d1b6_row3_col4" class="data row3 col4" >0.333333</td>
#       <td id="T_8d1b6_row3_col5" class="data row3 col5" >-1.333333</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row4_col0" class="data row4 col0" >Suíça</td>
#       <td id="T_8d1b6_row4_col1" class="data row4 col1" >77.777778</td>
#       <td id="T_8d1b6_row4_col2" class="data row4 col2" >2.333333</td>
#       <td id="T_8d1b6_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_8d1b6_row4_col4" class="data row4 col4" >2.333333</td>
#       <td id="T_8d1b6_row4_col5" class="data row4 col5" >1.333333</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row5_col0" class="data row5 col0" >Canadá</td>
#       <td id="T_8d1b6_row5_col1" class="data row5 col1" >44.444444</td>
#       <td id="T_8d1b6_row5_col2" class="data row5 col2" >2.666667</td>
#       <td id="T_8d1b6_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_8d1b6_row5_col4" class="data row5 col4" >1.333333</td>
#       <td id="T_8d1b6_row5_col5" class="data row5 col5" >1.666667</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row6_col0" class="data row6 col0" >Bósnia</td>
#       <td id="T_8d1b6_row6_col1" class="data row6 col1" >44.444444</td>
#       <td id="T_8d1b6_row6_col2" class="data row6 col2" >1.666667</td>
#       <td id="T_8d1b6_row6_col3" class="data row6 col3" >2.000000</td>
#       <td id="T_8d1b6_row6_col4" class="data row6 col4" >1.333333</td>
#       <td id="T_8d1b6_row6_col5" class="data row6 col5" >-0.333333</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row7_col0" class="data row7 col0" >Catar</td>
#       <td id="T_8d1b6_row7_col1" class="data row7 col1" >11.111111</td>
#       <td id="T_8d1b6_row7_col2" class="data row7 col2" >0.666667</td>
#       <td id="T_8d1b6_row7_col3" class="data row7 col3" >3.333333</td>
#       <td id="T_8d1b6_row7_col4" class="data row7 col4" >0.333333</td>
#       <td id="T_8d1b6_row7_col5" class="data row7 col5" >-2.666667</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row8_col0" class="data row8 col0" >Brasil</td>
#       <td id="T_8d1b6_row8_col1" class="data row8 col1" >77.777778</td>
#       <td id="T_8d1b6_row8_col2" class="data row8 col2" >2.333333</td>
#       <td id="T_8d1b6_row8_col3" class="data row8 col3" >0.333333</td>
#       <td id="T_8d1b6_row8_col4" class="data row8 col4" >2.333333</td>
#       <td id="T_8d1b6_row8_col5" class="data row8 col5" >2.000000</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row9_col0" class="data row9 col0" >Marrocos</td>
#       <td id="T_8d1b6_row9_col1" class="data row9 col1" >77.777778</td>
#       <td id="T_8d1b6_row9_col2" class="data row9 col2" >2.000000</td>
#       <td id="T_8d1b6_row9_col3" class="data row9 col3" >1.000000</td>
#       <td id="T_8d1b6_row9_col4" class="data row9 col4" >2.333333</td>
#       <td id="T_8d1b6_row9_col5" class="data row9 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row10_col0" class="data row10 col0" >Escócia</td>
#       <td id="T_8d1b6_row10_col1" class="data row10 col1" >33.333333</td>
#       <td id="T_8d1b6_row10_col2" class="data row10 col2" >0.333333</td>
#       <td id="T_8d1b6_row10_col3" class="data row10 col3" >1.333333</td>
#       <td id="T_8d1b6_row10_col4" class="data row10 col4" >1.000000</td>
#       <td id="T_8d1b6_row10_col5" class="data row10 col5" >-1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row11_col0" class="data row11 col0" >Haiti</td>
#       <td id="T_8d1b6_row11_col1" class="data row11 col1" >0.000000</td>
#       <td id="T_8d1b6_row11_col2" class="data row11 col2" >0.666667</td>
#       <td id="T_8d1b6_row11_col3" class="data row11 col3" >2.666667</td>
#       <td id="T_8d1b6_row11_col4" class="data row11 col4" >0.000000</td>
#       <td id="T_8d1b6_row11_col5" class="data row11 col5" >-2.000000</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row12_col0" class="data row12 col0" >Estados Unidos</td>
#       <td id="T_8d1b6_row12_col1" class="data row12 col1" >66.666667</td>
#       <td id="T_8d1b6_row12_col2" class="data row12 col2" >2.666667</td>
#       <td id="T_8d1b6_row12_col3" class="data row12 col3" >1.333333</td>
#       <td id="T_8d1b6_row12_col4" class="data row12 col4" >2.000000</td>
#       <td id="T_8d1b6_row12_col5" class="data row12 col5" >1.333333</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row13_col0" class="data row13 col0" >Austrália</td>
#       <td id="T_8d1b6_row13_col1" class="data row13 col1" >44.444444</td>
#       <td id="T_8d1b6_row13_col2" class="data row13 col2" >0.666667</td>
#       <td id="T_8d1b6_row13_col3" class="data row13 col3" >0.666667</td>
#       <td id="T_8d1b6_row13_col4" class="data row13 col4" >1.333333</td>
#       <td id="T_8d1b6_row13_col5" class="data row13 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row14_col0" class="data row14 col0" >Paraguai</td>
#       <td id="T_8d1b6_row14_col1" class="data row14 col1" >44.444444</td>
#       <td id="T_8d1b6_row14_col2" class="data row14 col2" >0.666667</td>
#       <td id="T_8d1b6_row14_col3" class="data row14 col3" >1.333333</td>
#       <td id="T_8d1b6_row14_col4" class="data row14 col4" >1.333333</td>
#       <td id="T_8d1b6_row14_col5" class="data row14 col5" >-0.666667</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row15_col0" class="data row15 col0" >Turquia</td>
#       <td id="T_8d1b6_row15_col1" class="data row15 col1" >33.333333</td>
#       <td id="T_8d1b6_row15_col2" class="data row15 col2" >1.000000</td>
#       <td id="T_8d1b6_row15_col3" class="data row15 col3" >1.666667</td>
#       <td id="T_8d1b6_row15_col4" class="data row15 col4" >1.000000</td>
#       <td id="T_8d1b6_row15_col5" class="data row15 col5" >-0.666667</td>
#     </tr>
#     <tr>
#       <td id="T_8d1b6_row16_col0" class="data row16 col0" >Alemanha</td>
#       <td id="T_8d1b6_row16_col1" class="data row16 col1" >66.666667</td>
#       <td id="T_8d1

# %%
print("4. Comparações")
# Out:
# 4. Comparações

# %%
print("Quem venceu mais também marcou mais gols?")
df.sort_values(["VIT", "GM"], ascending=False)[["Equipes", "VIT", "GM"]].style.hide(axis="index")
# Out:
# Quem venceu mais também marcou mais gols?
# <style type="text/css">
# </style>
# <table id="T_25c6c">
#   <thead>
#     <tr>
#       <th id="T_25c6c_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_25c6c_level0_col1" class="col_heading level0 col1" >VIT</th>
#       <th id="T_25c6c_level0_col2" class="col_heading level0 col2" >GM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_25c6c_row0_col0" class="data row0 col0" >França</td>
#       <td id="T_25c6c_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_25c6c_row0_col2" class="data row0 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row1_col0" class="data row1 col0" >Argentina</td>
#       <td id="T_25c6c_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_25c6c_row1_col2" class="data row1 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row2_col0" class="data row2 col0" >México</td>
#       <td id="T_25c6c_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_25c6c_row2_col2" class="data row2 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row3_col0" class="data row3 col0" >Alemanha</td>
#       <td id="T_25c6c_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_25c6c_row3_col2" class="data row3 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row4_col0" class="data row4 col0" >Holanda</td>
#       <td id="T_25c6c_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_25c6c_row4_col2" class="data row4 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row5_col0" class="data row5 col0" >Estados Unidos</td>
#       <td id="T_25c6c_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_25c6c_row5_col2" class="data row5 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row6_col0" class="data row6 col0" >Noruega</td>
#       <td id="T_25c6c_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_25c6c_row6_col2" class="data row6 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row7_col0" class="data row7 col0" >Suíça</td>
#       <td id="T_25c6c_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_25c6c_row7_col2" class="data row7 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row8_col0" class="data row8 col0" >Brasil</td>
#       <td id="T_25c6c_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_25c6c_row8_col2" class="data row8 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row9_col0" class="data row9 col0" >Marrocos</td>
#       <td id="T_25c6c_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_25c6c_row9_col2" class="data row9 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row10_col0" class="data row10 col0" >Inglaterra</td>
#       <td id="T_25c6c_row10_col1" class="data row10 col1" >2</td>
#       <td id="T_25c6c_row10_col2" class="data row10 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row11_col0" class="data row11 col0" >Espanha</td>
#       <td id="T_25c6c_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_25c6c_row11_col2" class="data row11 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row12_col0" class="data row12 col0" >Croácia</td>
#       <td id="T_25c6c_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_25c6c_row12_col2" class="data row12 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row13_col0" class="data row13 col0" >Costa do Marfim</td>
#       <td id="T_25c6c_row13_col1" class="data row13 col1" >2</td>
#       <td id="T_25c6c_row13_col2" class="data row13 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row14_col0" class="data row14 col0" >Colômbia</td>
#       <td id="T_25c6c_row14_col1" class="data row14 col1" >2</td>
#       <td id="T_25c6c_row14_col2" class="data row14 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row15_col0" class="data row15 col0" >Canadá</td>
#       <td id="T_25c6c_row15_col1" class="data row15 col1" >1</td>
#       <td id="T_25c6c_row15_col2" class="data row15 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row16_col0" class="data row16 col0" >Senegal</td>
#       <td id="T_25c6c_row16_col1" class="data row16 col1" >1</td>
#       <td id="T_25c6c_row16_col2" class="data row16 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row17_col0" class="data row17 col0" >Japão</td>
#       <td id="T_25c6c_row17_col1" class="data row17 col1" >1</td>
#       <td id="T_25c6c_row17_col2" class="data row17 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row18_col0" class="data row18 col0" >Suécia</td>
#       <td id="T_25c6c_row18_col1" class="data row18 col1" >1</td>
#       <td id="T_25c6c_row18_col2" class="data row18 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row19_col0" class="data row19 col0" >Bélgica</td>
#       <td id="T_25c6c_row19_col1" class="data row19 col1" >1</td>
#       <td id="T_25c6c_row19_col2" class="data row19 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row20_col0" class="data row20 col0" >Áustria</td>
#       <td id="T_25c6c_row20_col1" class="data row20 col1" >1</td>
#       <td id="T_25c6c_row20_col2" class="data row20 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row21_col0" class="data row21 col0" >Portugal</td>
#       <td id="T_25c6c_row21_col1" class="data row21 col1" >1</td>
#       <td id="T_25c6c_row21_col2" class="data row21 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row22_col0" class="data row22 col0" >Bósnia</td>
#       <td id="T_25c6c_row22_col1" class="data row22 col1" >1</td>
#       <td id="T_25c6c_row22_col2" class="data row22 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row23_col0" class="data row23 col0" >Egito</td>
#       <td id="T_25c6c_row23_col1" class="data row23 col1" >1</td>
#       <td id="T_25c6c_row23_col2" class="data row23 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row24_col0" class="data row24 col0" >Argélia</td>
#       <td id="T_25c6c_row24_col1" class="data row24 col1" >1</td>
#       <td id="T_25c6c_row24_col2" class="data row24 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row25_col0" class="data row25 col0" >RD Congo</td>
#       <td id="T_25c6c_row25_col1" class="data row25 col1" >1</td>
#       <td id="T_25c6c_row25_col2" class="data row25 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row26_col0" class="data row26 col0" >Turquia</td>
#       <td id="T_25c6c_row26_col1" class="data row26 col1" >1</td>
#       <td id="T_25c6c_row26_col2" class="data row26 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row27_col0" class="data row27 col0" >África do Sul</td>
#       <td id="T_25c6c_row27_col1" class="data row27 col1" >1</td>
#       <td id="T_25c6c_row27_col2" class="data row27 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row28_col0" class="data row28 col0" >Coreia do Sul</td>
#       <td id="T_25c6c_row28_col1" class="data row28 col1" >1</td>
#       <td id="T_25c6c_row28_col2" class="data row28 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row29_col0" class="data row29 col0" >Austrália</td>
#       <td id="T_25c6c_row29_col1" class="data row29 col1" >1</td>
#       <td id="T_25c6c_row29_col2" class="data row29 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row30_col0" class="data row30 col0" >Paraguai</td>
#       <td id="T_25c6c_row30_col1" class="data row30 col1" >1</td>
#       <td id="T_25c6c_row30_col2" class="data row30 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row31_col0" class="data row31 col0" >Equador</td>
#       <td id="T_25c6c_row31_col1" class="data row31 col1" >1</td>
#       <td id="T_25c6c_row31_col2" class="data row31 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row32_col0" class="data row32 col0" >Gana</td>
#       <td id="T_25c6c_row32_col1" class="data row32 col1" >1</td>
#       <td id="T_25c6c_row32_col2" class="data row32 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row33_col0" class="data row33 col0" >Escócia</td>
#       <td id="T_25c6c_row33_col1" class="data row33 col1" >1</td>
#       <td id="T_25c6c_row33_col2" class="data row33 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_25c6c_row34_col0" class="data row34 col0" >Nova Zelândia</td>
#       <td id="T_25c6c_row

# %%
print("Correlação entre saldo de gols e pontos:")
df[["SG", "Pts"]].corr().style.hide(axis="index")
# Out:
# Correlação entre saldo de gols e pontos:
# <style type="text/css">
# </style>
# <table id="T_4bb0c">
#   <thead>
#     <tr>
#       <th id="T_4bb0c_level0_col0" class="col_heading level0 col0" >SG</th>
#       <th id="T_4bb0c_level0_col1" class="col_heading level0 col1" >Pts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4bb0c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4bb0c_row0_col1" class="data row0 col1" >0.903108</td>
#     </tr>
#     <tr>
#       <td id="T_4bb0c_row1_col0" class="data row1 col0" >0.903108</td>
#       <td id="T_4bb0c_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Média de gols das 10 melhores equipes:")
top10 = df.nlargest(10, "Pts")
melhores = top10["GM"].mean()
print(melhores)
# Out:
# Média de gols das 10 melhores equipes:
# 6.9

# %%
print("5. Estatísticas gerais")
# Out:
# 5. Estatísticas gerais

# %%
print("Total de gols:")
gols = df["GM"].sum()
print(gols)
# Out:
# Total de gols:
# 215

# %%
print("Média de gols:")
Mgols = df["GM"].mean()
print(Mgols)
# Out:
# Média de gols:
# 4.479166666666667

# %%
print("Média de pontos:")
pontos = df["Pts"].mean()
print(pontos)
# Out:
# Média de pontos:
# 4.083333333333333

# %%
print("Média de vitórias:")
vitorias = df["VIT"].mean()
print(vitorias)
# Out:
# Média de vitórias:
# 1.0833333333333333

# %%
print("Média de empates:")
empates = df["E"].mean()
print(empates)
# Out:
# Média de empates:
# 0.8333333333333334

# %%
print("Média de derrotas:")
derrotas = df["DER"].mean()
print(derrotas)
# Out:
# Média de derrotas:
# 1.0833333333333333

# %%
print("Desvio padrão dos gols marcados:")
df["GM"].std()
# Out:
# Desvio padrão dos gols marcados:
# 2.7131639952734568

# %%
print("6. Rankings")
# Out:
# 6. Rankings

# %%
print("Top 10 ataques:")
df.nlargest(10, "GM")[["Equipes", "GM"]].style.hide(axis="index")
# Out:
# Top 10 ataques:
# <style type="text/css">
# </style>
# <table id="T_435f7">
#   <thead>
#     <tr>
#       <th id="T_435f7_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_435f7_level0_col1" class="col_heading level0 col1" >GM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_435f7_row0_col0" class="data row0 col0" >Alemanha</td>
#       <td id="T_435f7_row0_col1" class="data row0 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_435f7_row1_col0" class="data row1 col0" >Holanda</td>
#       <td id="T_435f7_row1_col1" class="data row1 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_435f7_row2_col0" class="data row2 col0" >França</td>
#       <td id="T_435f7_row2_col1" class="data row2 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_435f7_row3_col0" class="data row3 col0" >Canadá</td>
#       <td id="T_435f7_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_435f7_row4_col0" class="data row4 col0" >Estados Unidos</td>
#       <td id="T_435f7_row4_col1" class="data row4 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_435f7_row5_col0" class="data row5 col0" >Noruega</td>
#       <td id="T_435f7_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_435f7_row6_col0" class="data row6 col0" >Senegal</td>
#       <td id="T_435f7_row6_col1" class="data row6 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_435f7_row7_col0" class="data row7 col0" >Argentina</td>
#       <td id="T_435f7_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_435f7_row8_col0" class="data row8 col0" >Suíça</td>
#       <td id="T_435f7_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_435f7_row9_col0" class="data row9 col0" >Brasil</td>
#       <td id="T_435f7_row9_col1" class="data row9 col1" >7</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Top 10 defesas:")
df.nsmallest(10, "GC")[["Equipes", "GC"]].style.hide(axis="index")
# Out:
# Top 10 defesas:
# <style type="text/css">
# </style>
# <table id="T_e932b">
#   <thead>
#     <tr>
#       <th id="T_e932b_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_e932b_level0_col1" class="col_heading level0 col1" >GC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e932b_row0_col0" class="data row0 col0" >México</td>
#       <td id="T_e932b_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_e932b_row1_col0" class="data row1 col0" >Espanha</td>
#       <td id="T_e932b_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_e932b_row2_col0" class="data row2 col0" >Brasil</td>
#       <td id="T_e932b_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_e932b_row3_col0" class="data row3 col0" >Argentina</td>
#       <td id="T_e932b_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_e932b_row4_col0" class="data row4 col0" >Colômbia</td>
#       <td id="T_e932b_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_e932b_row5_col0" class="data row5 col0" >Portugal</td>
#       <td id="T_e932b_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_e932b_row6_col0" class="data row6 col0" >Austrália</td>
#       <td id="T_e932b_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_e932b_row7_col0" class="data row7 col0" >Costa do Marfim</td>
#       <td id="T_e932b_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_e932b_row8_col0" class="data row8 col0" >Equador</td>
#       <td id="T_e932b_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_e932b_row9_col0" class="data row9 col0" >Bélgica</td>
#       <td id="T_e932b_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Top 10 saldos:")
df.nlargest(10, "SG")[["Equipes", "SG"]].style.hide(axis="index")
# Out:
# Top 10 saldos:
# <style type="text/css">
# </style>
# <table id="T_e8373">
#   <thead>
#     <tr>
#       <th id="T_e8373_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_e8373_level0_col1" class="col_heading level0 col1" >SG</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e8373_row0_col0" class="data row0 col0" >França</td>
#       <td id="T_e8373_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_e8373_row1_col0" class="data row1 col0" >Argentina</td>
#       <td id="T_e8373_row1_col1" class="data row1 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_e8373_row2_col0" class="data row2 col0" >México</td>
#       <td id="T_e8373_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_e8373_row3_col0" class="data row3 col0" >Brasil</td>
#       <td id="T_e8373_row3_col1" class="data row3 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_e8373_row4_col0" class="data row4 col0" >Alemanha</td>
#       <td id="T_e8373_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_e8373_row5_col0" class="data row5 col0" >Holanda</td>
#       <td id="T_e8373_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_e8373_row6_col0" class="data row6 col0" >Canadá</td>
#       <td id="T_e8373_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_e8373_row7_col0" class="data row7 col0" >Espanha</td>
#       <td id="T_e8373_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_e8373_row8_col0" class="data row8 col0" >Portugal</td>
#       <td id="T_e8373_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_e8373_row9_col0" class="data row9 col0" >Suíça</td>
#       <td id="T_e8373_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Top 10 vitórias:")
df.nlargest(10, "VIT")[["Equipes", "VIT"]].style.hide(axis="index")
# Out:
# Top 10 vitórias:
# <style type="text/css">
# </style>
# <table id="T_2c5ee">
#   <thead>
#     <tr>
#       <th id="T_2c5ee_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_2c5ee_level0_col1" class="col_heading level0 col1" >VIT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2c5ee_row0_col0" class="data row0 col0" >México</td>
#       <td id="T_2c5ee_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_2c5ee_row1_col0" class="data row1 col0" >França</td>
#       <td id="T_2c5ee_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_2c5ee_row2_col0" class="data row2 col0" >Argentina</td>
#       <td id="T_2c5ee_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_2c5ee_row3_col0" class="data row3 col0" >Suíça</td>
#       <td id="T_2c5ee_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_2c5ee_row4_col0" class="data row4 col0" >Brasil</td>
#       <td id="T_2c5ee_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_2c5ee_row5_col0" class="data row5 col0" >Marrocos</td>
#       <td id="T_2c5ee_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_2c5ee_row6_col0" class="data row6 col0" >Estados Unidos</td>
#       <td id="T_2c5ee_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_2c5ee_row7_col0" class="data row7 col0" >Alemanha</td>
#       <td id="T_2c5ee_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_2c5ee_row8_col0" class="data row8 col0" >Costa do Marfim</td>
#       <td id="T_2c5ee_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_2c5ee_row9_col0" class="data row9 col0" >Holanda</td>
#       <td id="T_2c5ee_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#   </tbody>
# </table>
