# %%
#Importação das bibliotecas.
import pandas as pd 

df = pd.read_csv("Copa-do-Mundo-da-FIFA-2026.csv", index_col= False, sep= ";")
df
# Out:
#              Equipes  Pts  PJ  VIT  E  DER  GM  GC  SG
# 0             México    9   3    3  0    0   6   0   6
# 1      África do Sul    4   3    1  1    1   2   3  -1
# 2      Coreia do Sul    3   3    1  0    2   2   3  -1
# 3   República Tcheca    1   3    0  1    2   2   6  -4
# 4              Suíça    7   3    2  1    0   7   3   4
# 5             Canadá    4   3    1  1    1   8   3   5
# 6             Bósnia    4   3    1  1    1   5   6  -1
# 7              Catar    1   3    0  1    2   2  10  -8
# 8             Brasil    7   3    2  1    0   7   1   6
# 9           Marrocos    7   3    2  1    0   6   3   3
# 10           Escócia    3   3    1  0    2   1   4  -3
# 11             Haiti    0   3    0  0    3   2   8  -6
# 12    Estados Unidos    6   3    2  0    1   8   4   4
# 13         Austrália    4   3    1  1    1   2   2   0
# 14          Paraguai    4   3    1  1    1   2   4  -2
# 15           Turquia    3   3    1  0    2   3   5  -2
# 16          Alemanha    6   3    2  0    1  10   4   6
# 17   Costa do Marfim    6   3    2  0    1   4   2   2
# 18           Equador    4   3    1  1    1   2   2   0
# 19           Curacao    1   3    0  1    2   1   9  -8
# 20           Holanda    7   3    2  1    0  10   4   6
# 21             Japão    5   3    1  2    0   7   3   4
# 22            Suécia    4   3    1  1    1   7   7   0
# 23           Tunísia    0   3    0  0    3   2  12 -10
# 24           Bélgica    5   3    1  2    0   6   2   4
# 25             Egito    5   3    1  2    0   5   3   2
# 26               Irã    3   3    0  3    0   3   3   0
# 27     Nova Zelândia    1   3    0  1    2   4  10  -6
# 28           Espanha    7   3    2  1    0   5   0   5
# 29        Cabo Verde    3   3    0  3    0   2   2   0
# 30           Uruguai    2   3    0  2    1   3   4  -1
# 31    Arábia Saudita    2   3    0  2    1   1   5  -4
# 32            França    9   3    3  0    0  10   2   8
# 33           Noruega    6   3    2  0    1   8   7   1
# 34           Senegal    3   3    1  0    2   8   6   2
# 35            Iraque    0   3    0  0    3   1  12 -11
# 36         Argentina    9   3    3  0    0   8   1   7
# 37           Áustria    4   3    1  1    1   6   6   0
# 38           Argélia    4   3    1  1    1   5   7   0
# 39          Jordânia    0   3    0  0    3   3   8  -5
# 40          Colômbia    7   3    2  1    0   4   1   3
# 41          Portugal    5   3    1  2    0   6   1   5
# 42          RD Congo    4   3    1  1    1   4   3   1
# 43       Uzbequistão    0   3    0  0    3   2  11  -9
# 44        Inglaterra    7   3    2  1    0   6   2   4
# 45           Croácia    6   3    2  0    1   5   5   0
# 46              Gana    4   3    1  1    1   2   2   0
# 47            Panamá    0   3    0  0    3   0   4  -4

# %%
print("1. Desempenho das equipes")
# Out:
# 1. Desempenho das equipes

# %%
print("Qual seleção fez mais pontos?")
df.nlargest(1, "Pts")[["Equipes", "Pts"]].style.hide(axis="index")
# Out:
# Qual seleção fez mais pontos?
# <style type="text/css">
# </style>
# <table id="T_886cf">
#   <thead>
#     <tr>
#       <th id="T_886cf_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_886cf_level0_col1" class="col_heading level0 col1" >Pts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_886cf_row0_col0" class="data row0 col0" >México</td>
#       <td id="T_886cf_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Quais seleções terminaram invictas?")
df[df["DER"] == 0][["Equipes", "PJ", "VIT", "E", "DER"]].style.hide(axis="index")
# Out:
# Quais seleções terminaram invictas?
# <style type="text/css">
# </style>
# <table id="T_a4326">
#   <thead>
#     <tr>
#       <th id="T_a4326_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_a4326_level0_col1" class="col_heading level0 col1" >PJ</th>
#       <th id="T_a4326_level0_col2" class="col_heading level0 col2" >VIT</th>
#       <th id="T_a4326_level0_col3" class="col_heading level0 col3" >E</th>
#       <th id="T_a4326_level0_col4" class="col_heading level0 col4" >DER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a4326_row0_col0" class="data row0 col0" >México</td>
#       <td id="T_a4326_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_a4326_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_a4326_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a4326_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row1_col0" class="data row1 col0" >Suíça</td>
#       <td id="T_a4326_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_a4326_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_a4326_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_a4326_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row2_col0" class="data row2 col0" >Brasil</td>
#       <td id="T_a4326_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_a4326_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_a4326_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_a4326_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row3_col0" class="data row3 col0" >Marrocos</td>
#       <td id="T_a4326_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_a4326_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_a4326_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_a4326_row3_col4" class="data row3 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row4_col0" class="data row4 col0" >Holanda</td>
#       <td id="T_a4326_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_a4326_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_a4326_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_a4326_row4_col4" class="data row4 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row5_col0" class="data row5 col0" >Japão</td>
#       <td id="T_a4326_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_a4326_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_a4326_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_a4326_row5_col4" class="data row5 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row6_col0" class="data row6 col0" >Bélgica</td>
#       <td id="T_a4326_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_a4326_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_a4326_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_a4326_row6_col4" class="data row6 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row7_col0" class="data row7 col0" >Egito</td>
#       <td id="T_a4326_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_a4326_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_a4326_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_a4326_row7_col4" class="data row7 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row8_col0" class="data row8 col0" >Irã</td>
#       <td id="T_a4326_row8_col1" class="data row8 col1" >3</td>
#       <td id="T_a4326_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_a4326_row8_col3" class="data row8 col3" >3</td>
#       <td id="T_a4326_row8_col4" class="data row8 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row9_col0" class="data row9 col0" >Espanha</td>
#       <td id="T_a4326_row9_col1" class="data row9 col1" >3</td>
#       <td id="T_a4326_row9_col2" class="data row9 col2" >2</td>
#       <td id="T_a4326_row9_col3" class="data row9 col3" >1</td>
#       <td id="T_a4326_row9_col4" class="data row9 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row10_col0" class="data row10 col0" >Cabo Verde</td>
#       <td id="T_a4326_row10_col1" class="data row10 col1" >3</td>
#       <td id="T_a4326_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_a4326_row10_col3" class="data row10 col3" >3</td>
#       <td id="T_a4326_row10_col4" class="data row10 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row11_col0" class="data row11 col0" >França</td>
#       <td id="T_a4326_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_a4326_row11_col2" class="data row11 col2" >3</td>
#       <td id="T_a4326_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_a4326_row11_col4" class="data row11 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row12_col0" class="data row12 col0" >Argentina</td>
#       <td id="T_a4326_row12_col1" class="data row12 col1" >3</td>
#       <td id="T_a4326_row12_col2" class="data row12 col2" >3</td>
#       <td id="T_a4326_row12_col3" class="data row12 col3" >0</td>
#       <td id="T_a4326_row12_col4" class="data row12 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row13_col0" class="data row13 col0" >Colômbia</td>
#       <td id="T_a4326_row13_col1" class="data row13 col1" >3</td>
#       <td id="T_a4326_row13_col2" class="data row13 col2" >2</td>
#       <td id="T_a4326_row13_col3" class="data row13 col3" >1</td>
#       <td id="T_a4326_row13_col4" class="data row13 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row14_col0" class="data row14 col0" >Portugal</td>
#       <td id="T_a4326_row14_col1" class="data row14 col1" >3</td>
#       <td id="T_a4326_row14_col2" class="data row14 col2" >1</td>
#       <td id="T_a4326_row14_col3" class="data row14 col3" >2</td>
#       <td id="T_a4326_row14_col4" class="data row14 col4" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a4326_row15_col0" class="data row15 col0" >Inglaterra</td>
#       <td id="T_a4326_row15_col1" class="data row15 col1" >3</td>
#       <td id="T_a4326_row15_col2" class="data row15 col2" >2</td>
#       <td id="T_a4326_row15_col3" class="data row15 col3" >1</td>
#       <td id="T_a4326_row15_col4" class="data row15 col4" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Quais tiveram o pior desempenho?")
df.nsmallest(10, "Pts")[["Equipes", "Pts"]].style.hide(axis="index")
# Out:
# Quais tiveram o pior desempenho?
# <style type="text/css">
# </style>
# <table id="T_931cf">
#   <thead>
#     <tr>
#       <th id="T_931cf_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_931cf_level0_col1" class="col_heading level0 col1" >Pts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_931cf_row0_col0" class="data row0 col0" >Haiti</td>
#       <td id="T_931cf_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_931cf_row1_col0" class="data row1 col0" >Tunísia</td>
#       <td id="T_931cf_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_931cf_row2_col0" class="data row2 col0" >Iraque</td>
#       <td id="T_931cf_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_931cf_row3_col0" class="data row3 col0" >Jordânia</td>
#       <td id="T_931cf_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_931cf_row4_col0" class="data row4 col0" >Uzbequistão</td>
#       <td id="T_931cf_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_931cf_row5_col0" class="data row5 col0" >Panamá</td>
#       <td id="T_931cf_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_931cf_row6_col0" class="data row6 col0" >República Tcheca</td>
#       <td id="T_931cf_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_931cf_row7_col0" class="data row7 col0" >Catar</td>
#       <td id="T_931cf_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_931cf_row8_col0" class="data row8 col0" >Curacao</td>
#       <td id="T_931cf_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_931cf_row9_col0" class="data row9 col0" >Nova Zelândia</td>
#       <td id="T_931cf_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Quem venceu mais partidas?")
df.nlargest(10, "VIT")[["Equipes", "VIT"]].style.hide(axis="index")
# Out:
# Quem venceu mais partidas?
# <style type="text/css">
# </style>
# <table id="T_157aa">
#   <thead>
#     <tr>
#       <th id="T_157aa_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_157aa_level0_col1" class="col_heading level0 col1" >VIT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_157aa_row0_col0" class="data row0 col0" >México</td>
#       <td id="T_157aa_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_157aa_row1_col0" class="data row1 col0" >França</td>
#       <td id="T_157aa_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_157aa_row2_col0" class="data row2 col0" >Argentina</td>
#       <td id="T_157aa_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_157aa_row3_col0" class="data row3 col0" >Suíça</td>
#       <td id="T_157aa_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_157aa_row4_col0" class="data row4 col0" >Brasil</td>
#       <td id="T_157aa_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_157aa_row5_col0" class="data row5 col0" >Marrocos</td>
#       <td id="T_157aa_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_157aa_row6_col0" class="data row6 col0" >Estados Unidos</td>
#       <td id="T_157aa_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_157aa_row7_col0" class="data row7 col0" >Alemanha</td>
#       <td id="T_157aa_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_157aa_row8_col0" class="data row8 col0" >Costa do Marfim</td>
#       <td id="T_157aa_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_157aa_row9_col0" class="data row9 col0" >Holanda</td>
#       <td id="T_157aa_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Quem perdeu mais partidas?")
df.nlargest(10, "DER")[["Equipes", "DER"]].style.hide(axis="index")
# Out:
# Quem perdeu mais partidas?
# <style type="text/css">
# </style>
# <table id="T_5c498">
#   <thead>
#     <tr>
#       <th id="T_5c498_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_5c498_level0_col1" class="col_heading level0 col1" >DER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5c498_row0_col0" class="data row0 col0" >Haiti</td>
#       <td id="T_5c498_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5c498_row1_col0" class="data row1 col0" >Tunísia</td>
#       <td id="T_5c498_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5c498_row2_col0" class="data row2 col0" >Iraque</td>
#       <td id="T_5c498_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5c498_row3_col0" class="data row3 col0" >Jordânia</td>
#       <td id="T_5c498_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5c498_row4_col0" class="data row4 col0" >Uzbequistão</td>
#       <td id="T_5c498_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5c498_row5_col0" class="data row5 col0" >Panamá</td>
#       <td id="T_5c498_row5_col1" class="data row5 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_5c498_row6_col0" class="data row6 col0" >Coreia do Sul</td>
#       <td id="T_5c498_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_5c498_row7_col0" class="data row7 col0" >República Tcheca</td>
#       <td id="T_5c498_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_5c498_row8_col0" class="data row8 col0" >Catar</td>
#       <td id="T_5c498_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_5c498_row9_col0" class="data row9 col0" >Escócia</td>
#       <td id="T_5c498_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("2. Ataque e defesa")
# Out:
# 2. Ataque e defesa

# %%
print("Melhor ataque")
df.nlargest(10, "GM")[["Equipes", "GM"]].style.hide(axis="index")
# Out:
# Melhor ataque
# <style type="text/css">
# </style>
# <table id="T_e2cdc">
#   <thead>
#     <tr>
#       <th id="T_e2cdc_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_e2cdc_level0_col1" class="col_heading level0 col1" >GM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e2cdc_row0_col0" class="data row0 col0" >Alemanha</td>
#       <td id="T_e2cdc_row0_col1" class="data row0 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_e2cdc_row1_col0" class="data row1 col0" >Holanda</td>
#       <td id="T_e2cdc_row1_col1" class="data row1 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_e2cdc_row2_col0" class="data row2 col0" >França</td>
#       <td id="T_e2cdc_row2_col1" class="data row2 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_e2cdc_row3_col0" class="data row3 col0" >Canadá</td>
#       <td id="T_e2cdc_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_e2cdc_row4_col0" class="data row4 col0" >Estados Unidos</td>
#       <td id="T_e2cdc_row4_col1" class="data row4 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_e2cdc_row5_col0" class="data row5 col0" >Noruega</td>
#       <td id="T_e2cdc_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_e2cdc_row6_col0" class="data row6 col0" >Senegal</td>
#       <td id="T_e2cdc_row6_col1" class="data row6 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_e2cdc_row7_col0" class="data row7 col0" >Argentina</td>
#       <td id="T_e2cdc_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_e2cdc_row8_col0" class="data row8 col0" >Suíça</td>
#       <td id="T_e2cdc_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_e2cdc_row9_col0" class="data row9 col0" >Brasil</td>
#       <td id="T_e2cdc_row9_col1" class="data row9 col1" >7</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Melhor defesa")
df.nsmallest(10, "GC")[["Equipes", "GC"]].style.hide(axis="index")
# Out:
# Melhor defesa
# <style type="text/css">
# </style>
# <table id="T_ea026">
#   <thead>
#     <tr>
#       <th id="T_ea026_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_ea026_level0_col1" class="col_heading level0 col1" >GC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ea026_row0_col0" class="data row0 col0" >México</td>
#       <td id="T_ea026_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_ea026_row1_col0" class="data row1 col0" >Espanha</td>
#       <td id="T_ea026_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_ea026_row2_col0" class="data row2 col0" >Brasil</td>
#       <td id="T_ea026_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ea026_row3_col0" class="data row3 col0" >Argentina</td>
#       <td id="T_ea026_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ea026_row4_col0" class="data row4 col0" >Colômbia</td>
#       <td id="T_ea026_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ea026_row5_col0" class="data row5 col0" >Portugal</td>
#       <td id="T_ea026_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ea026_row6_col0" class="data row6 col0" >Austrália</td>
#       <td id="T_ea026_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_ea026_row7_col0" class="data row7 col0" >Costa do Marfim</td>
#       <td id="T_ea026_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_ea026_row8_col0" class="data row8 col0" >Equador</td>
#       <td id="T_ea026_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_ea026_row9_col0" class="data row9 col0" >Bélgica</td>
#       <td id="T_ea026_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Existe relação entre gols marcados e pontos?")
df[["GM", "Pts"]].corr().style.hide(axis="index")
#Se o valor estiver próximo de 1, existe uma forte relação positiva.
# Out:
# Existe relação entre gols marcados e pontos?
# <style type="text/css">
# </style>
# <table id="T_e1ea4">
#   <thead>
#     <tr>
#       <th id="T_e1ea4_level0_col0" class="col_heading level0 col0" >GM</th>
#       <th id="T_e1ea4_level0_col1" class="col_heading level0 col1" >Pts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e1ea4_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e1ea4_row0_col1" class="data row0 col1" >0.726668</td>
#     </tr>
#     <tr>
#       <td id="T_e1ea4_row1_col0" class="data row1 col0" >0.726668</td>
#       <td id="T_e1ea4_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Melhor saldo de gols")
df.nlargest(10, "SG")[["Equipes", "SG"]].style.hide(axis="index")
# Out:
# Melhor saldo de gols
# <style type="text/css">
# </style>
# <table id="T_b3a64">
#   <thead>
#     <tr>
#       <th id="T_b3a64_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_b3a64_level0_col1" class="col_heading level0 col1" >SG</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b3a64_row0_col0" class="data row0 col0" >França</td>
#       <td id="T_b3a64_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_b3a64_row1_col0" class="data row1 col0" >Argentina</td>
#       <td id="T_b3a64_row1_col1" class="data row1 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_b3a64_row2_col0" class="data row2 col0" >México</td>
#       <td id="T_b3a64_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_b3a64_row3_col0" class="data row3 col0" >Brasil</td>
#       <td id="T_b3a64_row3_col1" class="data row3 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_b3a64_row4_col0" class="data row4 col0" >Alemanha</td>
#       <td id="T_b3a64_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_b3a64_row5_col0" class="data row5 col0" >Holanda</td>
#       <td id="T_b3a64_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_b3a64_row6_col0" class="data row6 col0" >Canadá</td>
#       <td id="T_b3a64_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_b3a64_row7_col0" class="data row7 col0" >Espanha</td>
#       <td id="T_b3a64_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_b3a64_row8_col0" class="data row8 col0" >Portugal</td>
#       <td id="T_b3a64_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_b3a64_row9_col0" class="data row9 col0" >Suíça</td>
#       <td id="T_b3a64_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("3. Eficiência")
# Out:
# 3. Eficiência

# %%
df["Aproveitamento (%)"] = (df["Pts"] / (df["PJ"] * 3)) * 100

df["GM/Jogo"] = df["GM"] / df["PJ"]

df["GC/Jogo"] = df["GC"] / df["PJ"]

df["Pts/Jogo"] = df["Pts"] / df["PJ"]

df["SG/Jogo"] = df["SG"] / df["PJ"]

df
# Out:
#              Equipes  Pts  PJ  VIT  E  DER  GM  GC  SG  Aproveitamento (%)  \
# 0             México    9   3    3  0    0   6   0   6          100.000000
# 1      África do Sul    4   3    1  1    1   2   3  -1           44.444444
# 2      Coreia do Sul    3   3    1  0    2   2   3  -1           33.333333
# 3   República Tcheca    1   3    0  1    2   2   6  -4           11.111111
# 4              Suíça    7   3    2  1    0   7   3   4           77.777778
# 5             Canadá    4   3    1  1    1   8   3   5           44.444444
# 6             Bósnia    4   3    1  1    1   5   6  -1           44.444444
# 7              Catar    1   3    0  1    2   2  10  -8           11.111111
# 8             Brasil    7   3    2  1    0   7   1   6           77.777778
# 9           Marrocos    7   3    2  1    0   6   3   3           77.777778
# 10           Escócia    3   3    1  0    2   1   4  -3           33.333333
# 11             Haiti    0   3    0  0    3   2   8  -6            0.000000
# 12    Estados Unidos    6   3    2  0    1   8   4   4           66.666667
# 13         Austrália    4   3    1  1    1   2   2   0           44.444444
# 14          Paraguai    4   3    1  1    1   2   4  -2           44.444444
# 15           Turquia    3   3    1  0    2   3   5  -2           33.333333
# 16          Alemanha    6   3    2  0    1  10   4   6           66.666667
# 17   Costa do Marfim    6   3    2  0    1   4   2   2           66.666667
# 18           Equador    4   3    1  1    1   2   2   0           44.444444
# 19           Curacao    1   3    0  1    2   1   9  -8           11.111111
# 20           Holanda    7   3    2  1    0  10   4   6           77.777778
# 21             Japão    5   3    1  2    0   7   3   4           55.555556
# 22            Suécia    4   3    1  1    1   7   7   0           44.444444
# 23           Tunísia    0   3    0  0    3   2  12 -10            0.000000
# 24           Bélgica    5   3    1  2    0   6   2   4           55.555556
# 25             Egito    5   3    1  2    0   5   3   2           55.555556
# 26               Irã    3   3    0  3    0   3   3   0           33.333333
# 27     Nova Zelândia    1   3    0  1    2   4  10  -6           11.111111
# 28           Espanha    7   3    2  1    0   5   0   5           77.777778
# 29        Cabo Verde    3   3    0  3    0   2   2   0           33.333333
# 30           Uruguai    2   3    0  2    1   3   4  -1           22.222222
# 31    Arábia Saudita    2   3    0  2    1   1   5  -4           22.222222
# 32            França    9   3    3  0    0  10   2   8          100.000000
# 33           Noruega    6   3    2  0    1   8   7   1           66.666667
# 34           Senegal    3   3    1  0    2   8   6   2           33.333333
# 35            Iraque    0   3    0  0    3   1  12 -11            0.000000
# 36         Argentina    9   3    3  0    0   8   1   7          100.000000
# 37           Áustria    4   3    1  1    1   6   6   0           44.444444
# 38           Argélia    4   3    1  1    1   5   7   0           44.444444
# 39          Jordânia    0   3    0  0    3   3   8  -5            0.000000
# 40          Colômbia    7   3    2  1    0   4   1   3           77.777778
# 41          Portugal    5   3    1  2    0   6   1   5           55.555556
# 42          RD Congo    4   3    1  1    1   4   3   1           44.444444
# 43       Uzbequistão    0   3    0  0    3   2  11  -9            0.000000
# 44        Inglaterra    7   3    2  1    0   6   2   4           77.777778
# 45           Croácia    6   3    2  0    1   5   5   0           66.666667
# 46              Gana    4   3    1  1    1   2   2   0           44.444444
# 47            Panamá    0   3    0  0    3   0   4  -4            0.000000
#
#      GM/Jogo   GC/Jogo  Pts/Jogo   SG/Jogo
# 0   2.000000  0.000000  3.000000  2.000000
# 1   0.666667  1.000000  1.333333 -0.333333
# 2   0.666667  1.000000  1.000000 -0.333333
# 3   0.666667  2.000000  0.333333 -1.333333
# 4   2.333333  1.000000  2.333333  1.333333
# 5   2.666667  1.000000  1.333333  1.666667
# 6   1.666667  2.000000  1.333333 -0.333333
# 7   0.666667  3.333333  0.333333 -2.666667
# 8   2.333333  0.333333  2.333333  2.000000
# 9   2.000000  1.000000  2.333333  1.000000
# 10  0.333333  1.333333  1.000000 -1.000000
# 11  0.666667  2.666667  0.000000 -2.000000
# 12  2.666667  1.333333  2.000000  1.333333
# 13  0.666667  0.666667  1.333333  0.000000
# 14  0.666667  1.333333  1.333333 -0.666667
# 15  1.000000  1.666667  1.000000 -0.666667
# 16  3.333333  1.333333  2.000000  2.000000
# 17  1.333333  0.666667  2.000000  0.666667
# 18  0.666667  0.666667  1.333333  0.000000
# 19  0.333333  3.000000  0.333333 -2.666667
# 20  3.333333  1.333333  2.333333  2.000000
# 21  2.333333  1.000000  1.666667  1.333333
# 22  2.333333  2.333333  1.333333  0.000000
# 23  0.666667  4.000000  0.000000 -3.333333
# 24  2.000000  0.666667  1.666667  1.333333
# 25  1.666667  1.000000  1.666667  0.666667
# 26  1.000000  1.000000  1.000000  0.000000
# 27  1.333333  3.333333  0.333333 -2.000000
# 28  1.666667  0.000000  2.333333  1.666667
# 29  0.666667  0.666667  1.000000  0.000000
# 30  1.000000  1.333333  0.666667 -0.333333
# 31  0.333333  1.666667  0.666667 -1.333333
# 32  3.333333  0.666667  3.000000  2.666667
# 33  2.666667  2.333333  2.000000  0.333333
# 34  2.666667  2.000000  1.000000  0.666667
# 35  0.333333  4.000000  0.000000 -3.666667
# 36  2.666667  0.333333  3.000000  2.333333
# 37  2.000000  2.000000  1.333333  0.000000
# 38  1.666667  2.333333  1.333333  0.000000
# 39  1.000000  2.666667  0.000000 -1.666667
# 40  1.333333  0.333333  2.333333  1.000000
# 41  2.000000  0.333333  1.666667  1.666667
# 42  1.333333  1.000000  1.333333  0.333333
# 43  0.666667  3.666667  0.000000 -3.000000
# 44  2.000000  0.666667  2.333333  1.333333
# 45  1.666667  1.666667  2.000000  0.000000
# 46  0.666667  0.666667  1.333333  0.000000
# 47  0.000000  1.333333  0.000000 -1.333333

# %%
print("4. Comparações")
# Out:
# 4. Comparações

# %%
print("Quem venceu mais também marcou mais gols?")
df.sort_values(["VIT", "GM"], ascending=False)[["Equipes", "VIT", "GM"]].style.hide(axis="index")
# Out:
# Quem venceu mais também marcou mais gols?
# <style type="text/css">
# </style>
# <table id="T_45514">
#   <thead>
#     <tr>
#       <th id="T_45514_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_45514_level0_col1" class="col_heading level0 col1" >VIT</th>
#       <th id="T_45514_level0_col2" class="col_heading level0 col2" >GM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_45514_row0_col0" class="data row0 col0" >França</td>
#       <td id="T_45514_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_45514_row0_col2" class="data row0 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row1_col0" class="data row1 col0" >Argentina</td>
#       <td id="T_45514_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_45514_row1_col2" class="data row1 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row2_col0" class="data row2 col0" >México</td>
#       <td id="T_45514_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_45514_row2_col2" class="data row2 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row3_col0" class="data row3 col0" >Alemanha</td>
#       <td id="T_45514_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_45514_row3_col2" class="data row3 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row4_col0" class="data row4 col0" >Holanda</td>
#       <td id="T_45514_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_45514_row4_col2" class="data row4 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row5_col0" class="data row5 col0" >Estados Unidos</td>
#       <td id="T_45514_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_45514_row5_col2" class="data row5 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row6_col0" class="data row6 col0" >Noruega</td>
#       <td id="T_45514_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_45514_row6_col2" class="data row6 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row7_col0" class="data row7 col0" >Suíça</td>
#       <td id="T_45514_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_45514_row7_col2" class="data row7 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row8_col0" class="data row8 col0" >Brasil</td>
#       <td id="T_45514_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_45514_row8_col2" class="data row8 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row9_col0" class="data row9 col0" >Marrocos</td>
#       <td id="T_45514_row9_col1" class="data row9 col1" >2</td>
#       <td id="T_45514_row9_col2" class="data row9 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row10_col0" class="data row10 col0" >Inglaterra</td>
#       <td id="T_45514_row10_col1" class="data row10 col1" >2</td>
#       <td id="T_45514_row10_col2" class="data row10 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row11_col0" class="data row11 col0" >Espanha</td>
#       <td id="T_45514_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_45514_row11_col2" class="data row11 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row12_col0" class="data row12 col0" >Croácia</td>
#       <td id="T_45514_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_45514_row12_col2" class="data row12 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row13_col0" class="data row13 col0" >Costa do Marfim</td>
#       <td id="T_45514_row13_col1" class="data row13 col1" >2</td>
#       <td id="T_45514_row13_col2" class="data row13 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row14_col0" class="data row14 col0" >Colômbia</td>
#       <td id="T_45514_row14_col1" class="data row14 col1" >2</td>
#       <td id="T_45514_row14_col2" class="data row14 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row15_col0" class="data row15 col0" >Canadá</td>
#       <td id="T_45514_row15_col1" class="data row15 col1" >1</td>
#       <td id="T_45514_row15_col2" class="data row15 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row16_col0" class="data row16 col0" >Senegal</td>
#       <td id="T_45514_row16_col1" class="data row16 col1" >1</td>
#       <td id="T_45514_row16_col2" class="data row16 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row17_col0" class="data row17 col0" >Japão</td>
#       <td id="T_45514_row17_col1" class="data row17 col1" >1</td>
#       <td id="T_45514_row17_col2" class="data row17 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row18_col0" class="data row18 col0" >Suécia</td>
#       <td id="T_45514_row18_col1" class="data row18 col1" >1</td>
#       <td id="T_45514_row18_col2" class="data row18 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row19_col0" class="data row19 col0" >Bélgica</td>
#       <td id="T_45514_row19_col1" class="data row19 col1" >1</td>
#       <td id="T_45514_row19_col2" class="data row19 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row20_col0" class="data row20 col0" >Áustria</td>
#       <td id="T_45514_row20_col1" class="data row20 col1" >1</td>
#       <td id="T_45514_row20_col2" class="data row20 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row21_col0" class="data row21 col0" >Portugal</td>
#       <td id="T_45514_row21_col1" class="data row21 col1" >1</td>
#       <td id="T_45514_row21_col2" class="data row21 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row22_col0" class="data row22 col0" >Bósnia</td>
#       <td id="T_45514_row22_col1" class="data row22 col1" >1</td>
#       <td id="T_45514_row22_col2" class="data row22 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row23_col0" class="data row23 col0" >Egito</td>
#       <td id="T_45514_row23_col1" class="data row23 col1" >1</td>
#       <td id="T_45514_row23_col2" class="data row23 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row24_col0" class="data row24 col0" >Argélia</td>
#       <td id="T_45514_row24_col1" class="data row24 col1" >1</td>
#       <td id="T_45514_row24_col2" class="data row24 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row25_col0" class="data row25 col0" >RD Congo</td>
#       <td id="T_45514_row25_col1" class="data row25 col1" >1</td>
#       <td id="T_45514_row25_col2" class="data row25 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row26_col0" class="data row26 col0" >Turquia</td>
#       <td id="T_45514_row26_col1" class="data row26 col1" >1</td>
#       <td id="T_45514_row26_col2" class="data row26 col2" >3</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row27_col0" class="data row27 col0" >África do Sul</td>
#       <td id="T_45514_row27_col1" class="data row27 col1" >1</td>
#       <td id="T_45514_row27_col2" class="data row27 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row28_col0" class="data row28 col0" >Coreia do Sul</td>
#       <td id="T_45514_row28_col1" class="data row28 col1" >1</td>
#       <td id="T_45514_row28_col2" class="data row28 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row29_col0" class="data row29 col0" >Austrália</td>
#       <td id="T_45514_row29_col1" class="data row29 col1" >1</td>
#       <td id="T_45514_row29_col2" class="data row29 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row30_col0" class="data row30 col0" >Paraguai</td>
#       <td id="T_45514_row30_col1" class="data row30 col1" >1</td>
#       <td id="T_45514_row30_col2" class="data row30 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row31_col0" class="data row31 col0" >Equador</td>
#       <td id="T_45514_row31_col1" class="data row31 col1" >1</td>
#       <td id="T_45514_row31_col2" class="data row31 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row32_col0" class="data row32 col0" >Gana</td>
#       <td id="T_45514_row32_col1" class="data row32 col1" >1</td>
#       <td id="T_45514_row32_col2" class="data row32 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row33_col0" class="data row33 col0" >Escócia</td>
#       <td id="T_45514_row33_col1" class="data row33 col1" >1</td>
#       <td id="T_45514_row33_col2" class="data row33 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_45514_row34_col0" class="data row34 col0" >Nova Zelândia</td>
#       <td id="T_45514_row

# %%
print("Correlação entre saldo de gols e pontos")
df[["SG", "Pts"]].corr().style.hide(axis="index")
# Out:
# Correlação entre saldo de gols e pontos
# <style type="text/css">
# </style>
# <table id="T_c4d0a">
#   <thead>
#     <tr>
#       <th id="T_c4d0a_level0_col0" class="col_heading level0 col0" >SG</th>
#       <th id="T_c4d0a_level0_col1" class="col_heading level0 col1" >Pts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c4d0a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c4d0a_row0_col1" class="data row0 col1" >0.903108</td>
#     </tr>
#     <tr>
#       <td id="T_c4d0a_row1_col0" class="data row1 col0" >0.903108</td>
#       <td id="T_c4d0a_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Média de gols das 10 melhores equipes")
top10 = df.nlargest(10, "Pts")
melhores = top10["GM"].mean()
print(melhores)
# Out:
# Média de gols das 10 melhores equipes
# 6.9

# %%
print("5. Estatísticas gerais")
# Out:
# 5. Estatísticas gerais

# %%
print("Total de gols")
gols = df["GM"].sum()
print(gols)
# Out:
# Total de gols
# 215

# %%
print("Média de gols")
Mgols = df["GM"].mean()
print(Mgols)
# Out:
# Média de gols
# 4.479166666666667

# %%
print("Média de pontos")
pontos = df["Pts"].mean()
print(pontos)
# Out:
# Média de pontos
# 4.083333333333333

# %%
print("Média de vitórias")
vitorias = df["VIT"].mean()
print(vitorias)
# Out:
# Média de vitórias
# 1.0833333333333333

# %%
print("Média de empates")
empates = df["E"].mean()
print(empates)
# Out:
# Média de empates
# 0.8333333333333334

# %%
print("Média de derrotas")
derrotas = df["DER"].mean()
print(derrotas)
# Out:
# Média de derrotas
# 1.0833333333333333

# %%
print("Desvio padrão dos gols marcados")
df["GM"].std()
# Out:
# Desvio padrão dos gols marcados
# 2.7131639952734568

# %%
print("6. Rankings")
# Out:
# 6. Rankings

# %%
print("Top 10 ataques")
df.nlargest(10, "GM")[["Equipes", "GM"]].style.hide(axis="index")
# Out:
# Top 10 ataques
# <style type="text/css">
# </style>
# <table id="T_7f81e">
#   <thead>
#     <tr>
#       <th id="T_7f81e_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_7f81e_level0_col1" class="col_heading level0 col1" >GM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7f81e_row0_col0" class="data row0 col0" >Alemanha</td>
#       <td id="T_7f81e_row0_col1" class="data row0 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_7f81e_row1_col0" class="data row1 col0" >Holanda</td>
#       <td id="T_7f81e_row1_col1" class="data row1 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_7f81e_row2_col0" class="data row2 col0" >França</td>
#       <td id="T_7f81e_row2_col1" class="data row2 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_7f81e_row3_col0" class="data row3 col0" >Canadá</td>
#       <td id="T_7f81e_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_7f81e_row4_col0" class="data row4 col0" >Estados Unidos</td>
#       <td id="T_7f81e_row4_col1" class="data row4 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_7f81e_row5_col0" class="data row5 col0" >Noruega</td>
#       <td id="T_7f81e_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_7f81e_row6_col0" class="data row6 col0" >Senegal</td>
#       <td id="T_7f81e_row6_col1" class="data row6 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_7f81e_row7_col0" class="data row7 col0" >Argentina</td>
#       <td id="T_7f81e_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_7f81e_row8_col0" class="data row8 col0" >Suíça</td>
#       <td id="T_7f81e_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_7f81e_row9_col0" class="data row9 col0" >Brasil</td>
#       <td id="T_7f81e_row9_col1" class="data row9 col1" >7</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Top 10 defesas")
df.nsmallest(10, "GC")[["Equipes", "GC"]].style.hide(axis="index")
# Out:
# Top 10 defesas
# <style type="text/css">
# </style>
# <table id="T_241de">
#   <thead>
#     <tr>
#       <th id="T_241de_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_241de_level0_col1" class="col_heading level0 col1" >GC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_241de_row0_col0" class="data row0 col0" >México</td>
#       <td id="T_241de_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_241de_row1_col0" class="data row1 col0" >Espanha</td>
#       <td id="T_241de_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_241de_row2_col0" class="data row2 col0" >Brasil</td>
#       <td id="T_241de_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_241de_row3_col0" class="data row3 col0" >Argentina</td>
#       <td id="T_241de_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_241de_row4_col0" class="data row4 col0" >Colômbia</td>
#       <td id="T_241de_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_241de_row5_col0" class="data row5 col0" >Portugal</td>
#       <td id="T_241de_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_241de_row6_col0" class="data row6 col0" >Austrália</td>
#       <td id="T_241de_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_241de_row7_col0" class="data row7 col0" >Costa do Marfim</td>
#       <td id="T_241de_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_241de_row8_col0" class="data row8 col0" >Equador</td>
#       <td id="T_241de_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_241de_row9_col0" class="data row9 col0" >Bélgica</td>
#       <td id="T_241de_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Top 10 saldos")
df.nlargest(10, "SG")[["Equipes", "SG"]].style.hide(axis="index")
# Out:
# Top 10 saldos
# <style type="text/css">
# </style>
# <table id="T_21067">
#   <thead>
#     <tr>
#       <th id="T_21067_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_21067_level0_col1" class="col_heading level0 col1" >SG</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_21067_row0_col0" class="data row0 col0" >França</td>
#       <td id="T_21067_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_21067_row1_col0" class="data row1 col0" >Argentina</td>
#       <td id="T_21067_row1_col1" class="data row1 col1" >7</td>
#     </tr>
#     <tr>
#       <td id="T_21067_row2_col0" class="data row2 col0" >México</td>
#       <td id="T_21067_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_21067_row3_col0" class="data row3 col0" >Brasil</td>
#       <td id="T_21067_row3_col1" class="data row3 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_21067_row4_col0" class="data row4 col0" >Alemanha</td>
#       <td id="T_21067_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_21067_row5_col0" class="data row5 col0" >Holanda</td>
#       <td id="T_21067_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_21067_row6_col0" class="data row6 col0" >Canadá</td>
#       <td id="T_21067_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_21067_row7_col0" class="data row7 col0" >Espanha</td>
#       <td id="T_21067_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_21067_row8_col0" class="data row8 col0" >Portugal</td>
#       <td id="T_21067_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_21067_row9_col0" class="data row9 col0" >Suíça</td>
#       <td id="T_21067_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Top 10 vitórias")
df.nlargest(10, "VIT")[["Equipes", "VIT"]].style.hide(axis="index")
# Out:
# Top 10 vitórias
# <style type="text/css">
# </style>
# <table id="T_33645">
#   <thead>
#     <tr>
#       <th id="T_33645_level0_col0" class="col_heading level0 col0" >Equipes</th>
#       <th id="T_33645_level0_col1" class="col_heading level0 col1" >VIT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_33645_row0_col0" class="data row0 col0" >México</td>
#       <td id="T_33645_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_33645_row1_col0" class="data row1 col0" >França</td>
#       <td id="T_33645_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_33645_row2_col0" class="data row2 col0" >Argentina</td>
#       <td id="T_33645_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_33645_row3_col0" class="data row3 col0" >Suíça</td>
#       <td id="T_33645_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_33645_row4_col0" class="data row4 col0" >Brasil</td>
#       <td id="T_33645_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_33645_row5_col0" class="data row5 col0" >Marrocos</td>
#       <td id="T_33645_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_33645_row6_col0" class="data row6 col0" >Estados Unidos</td>
#       <td id="T_33645_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_33645_row7_col0" class="data row7 col0" >Alemanha</td>
#       <td id="T_33645_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_33645_row8_col0" class="data row8 col0" >Costa do Marfim</td>
#       <td id="T_33645_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_33645_row9_col0" class="data row9 col0" >Holanda</td>
#       <td id="T_33645_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#   </tbody>
# </table>
